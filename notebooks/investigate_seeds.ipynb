# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scanpy as sc 
import sys
sys.path.append("../utils")
from plotting_utils import format_top_3, plot_metric_grouped_by, plot_bio_vs_batch_correction
# Out:
# /NOBACKUP/lizottem/fosta/.condaenv/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
# %load_ext autoreload
# %autoreload 2

# %%
path1 = "/NOBACKUP/lizottem/fosta/results/real_batches_lung/2026-04-29_17-03-48/A1_A2/adata_intermediate.h5ad"
path2 = "/NOBACKUP/lizottem/fosta/results/real_batches_lung_test/test_seed/A1_A2/adata_intermediate.h5ad"
adata1 = sc.read_h5ad(path1)
adata2 = sc.read_h5ad(path2)
# Out:
# /NOBACKUP/lizottem/fosta/.condaenv/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
adata1
# Out:
# AnnData object with n_obs × n_vars = 3299 × 2000
#     obs: 'dataset', 'location', 'nGene', 'nUMI', 'patientGroup', 'percent.mito', 'protocol', 'sanger_type', 'size_factors', 'sampling_method', 'batch', 'cell_type', 'donor', 'cell_type_masked', 'mask_indices', 'cell_type_cleaned_encoded', '_scvi_batch', '_scvi_labels'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'hvg', 'memory_dict', 'pca', 'times_dict'
#     obsm: 'FoSTA gap t=2', 'FoSTA gap t=2 avg', 'FoSTA gap t=auto', 'FoSTA gap t=auto avg', 'FoSTA kerf t=2', 'FoSTA kerf t=2 avg', 'FoSTA kerf t=auto', 'FoSTA kerf t=auto avg', 'Harmony', 'KEMAlin', 'KEMArbf', 'LIGER', 'Pamona', 'Scanorama', 'Unintegrated', 'X_pca', 'scANVI', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'

# %%
(adata2.obs['mask_indices'] == adata1.obs['mask_indices']).all()
# Out:
# True

# %%
(adata2.obsm['Unintegrated'] == adata1.obsm['Unintegrated']).all()
# Out:
# True

# %%
adata1.uns.keys()
# Out:
# dict_keys(['_scvi_manager_uuid', '_scvi_uuid', 'hvg', 'memory_dict', 'pca', 'times_dict'])

# %%
adata2.uns["global_masking_fraction"]
# Out:
# 0.2

# %%
for method in adata1.obsm.keys():
    print(method)
    print((adata1.obsm[method] == adata2.obsm[method]).all())
    print(np.allclose(adata1.obsm[method], adata2.obsm[method]))
# Out:
# FoSTA gap t=2
# True
# True
# FoSTA gap t=2 avg
# True
# True
# FoSTA gap t=auto
# True
# True
# FoSTA gap t=auto avg
# True
# True
# FoSTA kerf t=2
# True
# True
# FoSTA kerf t=2 avg
# True
# True
# FoSTA kerf t=auto
# True
# True
# FoSTA kerf t=auto avg
# True
# True
# Harmony
# False
# False
# KEMAlin
# True
# True
# KEMArbf
# True
# True
# LIGER
# True
# True
# Pamona
# True
# True
# Scanorama
# True
# True
# Unintegrated
# True
# True
# X_pca
# True
# True
# scANVI
# False
# False
# scVI
# True
# True

# %% [markdown]
# # Second run

# %%
path1="/NOBACKUP/lizottem/fosta/results/real_batches_lung/test_seed1/real_batches_lung_results.csv"
path2="/NOBACKUP/lizottem/fosta/results/real_batches_lung/test_seed2/real_batches_lung_results.csv"

results1 = pd.read_csv(path1)
results2 = pd.read_csv(path2)

# %%
results1.set_index("method", inplace=True)
results2.set_index("method", inplace=True)

# %%
results1.drop("Metric Type", axis=0, inplace=True)
results2.drop("Metric Type", axis=0, inplace=True)

results1.drop("time", axis=1, inplace=True)
results2.drop("time", axis=1, inplace=True)
results1.drop("memory", axis=1, inplace=True)
results2.drop("memory", axis=1, inplace=True)

# %%
(np.abs(results1.astype(float) - results2.astype(float)) > 10**-7).any()
# Out:
# n_components          False
# Isolated labels        True
# Leiden NMI            False
# Leiden ARI            False
# KMeans NMI            False
# KMeans ARI            False
# Silhouette label      False
# cLISI                 False
# BRAS                   True
# iLISI                  True
# KBET                  False
# Graph connectivity    False
# PCR comparison         True
# Batch correction       True
# Bio conservation      False
# Total                  True
# cell_cycle_score      False
# dtype: bool

# %%
results1-results2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /NOBACKUP/lizottem/fosta/.condaenv/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File /NOBACKUP/lizottem/fosta/.condaenv/lib/python3.10/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /NOBACKUP/lizottem/fosta/.condaenv/lib/python3.10/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
# ...

# %%
results1 == results2
# Out:
#     n_components  method  Isolated labels  Leiden NMI  Leiden ARI  KMeans NMI  \
# 0           True    True             True        True        True        True
# 1           True    True             True        True        True        True
# 2           True    True             True        True        True        True
# 3           True    True             True        True        True        True
# 4           True    True             True        True        True        True
# 5           True    True            False        True        True        True
# 6           True    True             True        True        True        True
# 7           True    True             True        True        True        True
# 8           True    True             True        True        True        True
# 9           True    True             True        True        True        True
# 10          True    True             True        True        True        True
# ...

# %%
adata_path1="/NOBACKUP/lizottem/fosta/results/real_batches_lung/test_seed1/A1_A2/adata_intermediate.h5ad"
adata_path2="/NOBACKUP/lizottem/fosta/results/real_batches_lung/test_seed2/A1_A2/adata_intermediate.h5ad"

adata1 = sc.read_h5ad(adata_path1)
adata2 = sc.read_h5ad(adata_path2)

# %%
for method in adata1.obsm.keys():
    print(method)
    print((adata1.obsm[method] == adata2.obsm[method]).all())
    print(np.allclose(adata1.obsm[method], adata2.obsm[method]))
# Out:
# FoSTA gap t=2
# True
# True
# FoSTA gap t=2 avg
# True
# True
# FoSTA gap t=auto
# True
# True
# FoSTA gap t=auto avg
# True
# True
# FoSTA kerf t=2
# True
# True
# FoSTA kerf t=2 avg
# True
# True
# FoSTA kerf t=auto
# True
# True
# FoSTA kerf t=auto avg
# True
# True
# Harmony
# False
# False
# KEMAlin
# True
# True
# KEMArbf
# True
# True
# LIGER
# True
# True
# Pamona
# True
# True
# Scanorama
# True
# True
# Unintegrated
# True
# True
# X_pca
# True
# True
# scANVI
# True
# True
# scVI
# True
# True
